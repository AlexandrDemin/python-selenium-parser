# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from datetime import date
import smtplib
from email import encoders
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.utils import formatdate

# %%
driver = webdriver.Chrome()
driver.get("http://www.zakupki.rosatom.ru/Web.aspx?node=currentorders&ostate=P")

#ищу ссылку для открытия формы фильтрации
elem = driver.find_element_by_id("control-filter-lots")
elem.click()

#определяю текущую дату
dtnow = date.today().strftime("%d.%m.%Y")
dtnow = "25.03.2019" #тестовая дата

#заполняю дату
fieldDate = driver.find_element_by_name("ctl09$ctl06$ctl02$dps$txtDate")
fieldDate.send_keys(dtnow)

#нажимаю поиск
btnSearch = driver.find_element_by_name("ctl09$ctl06$ctl02$bSearch")
btnSearch.click()

page=1
curString=1

# %%
btns = driver.find_elements_by_xpath("//td[@class='control']/img[@class='btm']")
for t in range(len(btns)):
    btns[t].click()

nums = driver.find_elements_by_xpath("//table/tbody/tr/td[@class='description']/p[1]")
links = driver.find_elements_by_xpath("//table/tbody/tr/td[@class='description']/p[2]/a")
prices = driver.find_elements_by_xpath("//table/tbody/tr/td[@class='price text-right']/p[1]")
customers = driver.find_elements_by_xpath("//table/tbody/tr[((contains(@class,'odd') or contains(@class,'even')) and not (contains(@class,'description')))]/td[5]/p")
types = driver.find_elements_by_xpath("//div[@class='description']/p[2]/strong")

# %%
data = []
for num, link, price, customer, typ in zip(nums, links, prices, customers, types):
    data.append({
        'num': num.text,
        'linkText': link.text,
        'link': link.get_attribute('href'),
        'price': price.text.replace(" ", "").replace(",", "."),
        'customer': customer.text,
        'type': typ.text
    })
data
# Out:
# [{'customer': 'Акционерное общество "Инжиниринговая компания "АЭМ-технологии"',
#   'link': 'http://www.zakupki.rosatom.ru/1908220594246',
#   'linkText': 'Право заключения договора на передачу неисключительных прав, экземпляров ПО и ключей активации на СКЗИ',
#   'num': '190822/0594/246',
#   'price': '557513.05',
#   'type': 'Запрос котировок в электронной форме'},
#  {'customer': 'Акционерное общество "НПК "Химпроминжиниринг"',
#   'link': 'http://www.zakupki.rosatom.ru/1908220712077',
#   'linkText': 'Оказание услуг по по разработке программы производственного экологического контроля с инвентаризацией источников негативного воздействия на окружающую среду в НИЦ АО «НПК «Химпроминжиниринг» и по постановке на государственный учет АО «НПК «Химпроминжиниринг» как объекта, оказывающего негативное воздействие на окружающую среду',
#   'num': '190822/0712/077',
#   'price': '230000.00',
#   'type': 'Мелкая закупка'},
#  {'customer': 'Акционерное общество "Атомное и энергетическое машиностроение"',
#   'link': 'http://www.zakupki.rosatom.ru/1908050593061',
#   'linkText': 'Работы по реализации экологической политики',
#   'num': '190805/0593/061',
#   'price': '3740000.00',
#   'type': 'Прямая закупка у единственного поставщика'},
#  {'customer': 'Акционерное общество "Радиевый институт имени В.Г. Хлопина"',
#   'link': 'http://www.zakupki.rosatom.ru/1908220495153',
#   'linkText': 'Предоставление услуг на поставку тепловой энергии для корпусов площадки № 4 АО "Радиевый институт им. В.Г. Хлопина", расположенных по адресу: Ленинградская область, г. Сосновый Бор, промзона, площадка Радиевого института. Д/С № 10',
#   'num': '190822/0495/153',
#   'price': '4080000.00',
#   'type': 'Прямая закупка у единственного поставщика'},
#  {'customer': 'Акционерное общество "Государственный научный центр - Научно-исследовательский институт атомных реакторов"',
#   'link': 'http://www.zakupki.rosatom.ru/1908220497329',
#   'linkText': 'Право заключения договора на поставку дверей металлических противопожарных',
#   'num': '190822/0497/329',
#   'price': '209284.00',
#   'type': 'Запрос котировок в электронной форме среди субъектов МСП'},
#  {'customer': 'Федеральное государственное унитарное предприятие "Объединенный эколого-технологический и научно-исследовательский центр по обезвреживанию РАО и охране окружающей среды"',
#   'link': 'http://www.zakupki.rosatom.ru/1908224768326',
#   'linkText': 'Выполнение работ по вывозу с площадки ФГУП "РАДОН", приведение к критериям приемлемости для захоронения и размещение на промежуточное хранение контейнеров с РАО',
#   'num': '190822/4768/326',
#   'price': '158147595.81',
#   'type': 'Закупка во исполнение доходных договоров'},
#  {'customer': 'Акционерное общество "Производственное объединение "Машиностроительный завод "Молния"',
#   'link': 'http://www.zakupki.rosatom.ru/1908220522001',
#   'linkText': 'Услуги по определению рыночной стоимости имущества (ИК АО «ПО «МЗ «Молния»',
#   'num': '190822/0522/001',
#   'price': '168000.00',
#   'type': 'Мелкая закупка'},
#  {'customer': 'Государственная корпорация по атомной энергии "Росатом"',
#   'link': 'http://www.zakupki.rosatom.ru/1908190451233',
#   'linkText': 'Проведение анализа отраслевых отчетных документов и подготовка методических рекомендаций по проектам «Дни информирования» и «Дни директора»',
#   'num': '190819/0451/233',
#   'price': '900000.00',
#   'type': 'Мелкая закупка'},
#  {'customer': 'Федеральное государственное унитарное предприятие "Московское опытно-конструкторское бюро "Марс"',
#   'link': 'http://www.zakupki.rosatom.ru/19082258357047',
#   'linkText': 'Право заключения договора на Программное обеспечение Электронная лицензия Microsoft Windows Professional 10 a Single OLV NL Each Legalization GetGenuine wCOA полная бессрочная Электронная лицензия Microsoft Office Standard 2019 Single OLV NL Each Additional Product полная бессрочная ПО Kaspersky Endpoint Security для бизнеса – Стандартный Russian Edition. 250-499 Node 1 year Base License дозакупка к действующей лицензии № 1688\xad190115\xad140710\xad437\xad1392',
#   'num': '190822/58357/047',
#   'price': '3717020.65',
#   'type': 'Запрос предложений в электронной форме среди субъектов МСП'},
#  {'customer': 'Филиал ОАО "Концерн Росэнергоатом" "Белоярская атомная станция"',
#   'link': 'http://www.zakupki.rosatom.ru/1908220670423',
#   'linkText': 'Право заключения договора на Разработка рабочей документации на замену электротехнического оборудования Белоярской АЭС в соответствии с Техническим заданием',
#   'num': '190822/0670/423',
#   'price': '19949429.45',
#   'type': 'Конкурс в электронной форме среди субъектов МСП'},
#  {'customer': 'Акционерное общество "Атомэнергоремонт"',
#   'link': 'http://www.zakupki.rosatom.ru/1908220550273',
#   'linkText': 'поставка трубы стальной',
#   'num': '190822/0550/273',
#   'price': '999460.00',
#   'type': 'Мелкая закупка'},
#  {'customer': 'Автономная некоммерческая организация "Корпоративная Академия Госкорпорации "Росатом"',
#   'link': 'http://www.zakupki.rosatom.ru/1908223595160',
#   'linkText': 'Право заключения договора на оказание услуг по созданию тематического раздела (страницы) о российском атомном образовании, модуля мониторинга приема иностранных абитуриентов и обучения иностранных студентов в университетах-партнерах Госкорпорации «Росатом» по атомным специальностям на портале Russia.Study, разработка системы визуальной идентификации и стартовой рекламной кампании продукта Russian Nuclear Education (Российское ядерное образование)',
#   'num': '190822/3595/160',
#   'price': '8142000.00',
#   'type': 'Запрос предложений в электронной форме'},
#  {'customer': 'Федеральное государственное унитарное предприятие "Московское опытно-конструкторское бюро "Марс"',
#   'link': 'http://www.zakupki.rosatom.ru/19082258357046',
#   'linkText': 'Право заключения договора на Программное обсепечение Microsoft Project 2019 Standard Single Open Value No Level Each Additional Product Электронная лицензия 076-05854 Полная бессрочная лицензия',
#   'num': '190822/58357/046',
#   'price': '167437.20',
#   'type': 'Запрос предложений в электронной форме среди субъектов МСП'},
#  {'customer': 'Акционерное общество "Атомкомплект"',
#   'link': 'http://www.zakupki.rosatom.ru/1908221065335',
#   'linkText': 'Право заключения договора на изготовление и поставку технических средств программно-технического комплекса системы контроля и управления электротехническим оборудованием общестанционных собственных нужд (ТС ПТК СКУ ЭЧ ОС СН) для энергоблоков №№ 1,2 Курской АЭС-2',
#   'num': '190822/1065/335',
#   'price': '165546355.30',
#   'type': 'Запрос предложений в электронной форме'},
#  {'customer': 'Акционерное общество "Атомкомплект"',
#   'link': 'http://www.zakupki.rosatom.ru/1908221065334',
#   'linkText': 'Право заключения договора на Лот № 403. Курская АЭС-2. Энергоблоки №1и 2. Мастерские зоны контролируемого доступа (00UKU) c вентиляционной трубой (02UKH). Разделы С, АЗ, ВК, ОВ, ПТ, Т',
#   'num': '190822/1065/334',
#   'price': '671666096.40',
#   'type': 'Конкурс в электронной форме'},
#  {'customer': 'Федеральное государственное унитарное предприятие "Национальный оператор по обращению с радиоактивными отходами"',
#   'link': 'http://www.zakupki.rosatom.ru/1908140482147',
#   'linkText': 'Оказание услуг по публикации в электронных Интернет-изданиях информационных материалов о безопасности обращения с радиоактивными отходами для нужд ФГУП «НО РАО».',
#   'num': '190814/0482/147',
#   'price': '950000.00',
#   'type': 'Мелкая закупка'},
#  {'customer': 'Акционерное общество "Атомстройэкспорт"',
#   'link': 'http://www.zakupki.rosatom.ru/1908190591200',
#   'linkText': 'Авторский надзор за строительством зданий и сооружений АЭС, блоки 1,2 , входящих в объем АО "Атомэнергопроект"',
#   'num': '190819/0591/200',
#   'price': '1780559574.93',
#   'type': 'Прямая закупка у единственного поставщика'},
#  {'customer': 'Акционерное общество "Радиевый институт имени В.Г. Хлопина"',
#   'link': 'http://www.zakupki.rosatom.ru/1908130495151',
#   'linkText': 'Поставка свинцовой защиты',
#   'num': '190813/0495/151',
#   'price': '118000.00',
#   'type': 'Мелкая закупка'},
#  {'customer': 'Акционерное общество "Радиевый институт имени В.Г. Хлопина"',
#   'link': 'http://www.zakupki.rosatom.ru/1908130495152',
#   'linkText': 'Поставка модулей и преобразователей',
#   'num': '190813/0495/152',
#   'price': '182184.00',
#   'type': 'Мелкая закупка'},
#  {'customer': 'Автономная некоммерческая организация "Корпоративная Академия Госкорпорации "Росатом"',
#   'link': 'http://www.zakupki.rosatom.ru/1908223595159',
#   'linkText': 'Право заключения договора на оказание услуг по разработке и обновлению содержания и проведению курса «Управление развитием компетенции в отрасли» в очном и дистанционном (при помощи вебинаров) формате',
#   'num': '190822/3595/159',
#   'price': '2648000.00',
#   'type': 'Запрос предложений в электронной форме'},
#  {'customer': 'Акционерное общество "Федеральный центр науки и высоких технологий "Специальное научно-производственное объединение "Элерон"',
#   'link': 'http://www.zakupki.rosatom.ru/1908225610511',
#   'linkText': 'Право заключения договора на поставку портативных обнаружителей паров взрывчатых веществ',
#   'num': '190822/5610/511',
#   'price': '25920000.00',
#   'type': 'Аукцион в электронной форме среди субъектов МСП'},
#  {'customer': 'Акционерное общество "Государственный научный центр - Научно-исследовательский институт атомных реакторов"',
#   'link': 'http://www.zakupki.rosatom.ru/1908220497328',
#   'linkText': 'Право заключения договора на поставку дерматологических средств индивидуальной защиты (ДСИЗ)',
#   'num': '190822/0497/328',
#   'price': '429519.88',
#   'type': 'Запрос котировок в электронной форме среди субъектов МСП'},
#  {'customer': 'Акционерное общество "Российский концерн по производству электрической и тепловой энергии на атомных станциях"',
#   'link': 'http://www.zakupki.rosatom.ru/19082205131242',
#   'linkText': 'Право заключения договора на Оказание услуг по проведению тренингов инспекторскому персоналу АО "Концерн Росэнергоатом" с целью повышения эффективности инспекционного контроля за обеспечением ядерной и радиационной безопасности АС в рамках реализации ответных мер после Корпоративной миссии ОСАРТ МАГАТЭ и внедрения Руководства ВАО АЭС «Независимый надзор» GL 2018-01',
#   'num': '190822/0513/1242',
#   'price': '9600000.00',
#   'type': 'Запрос предложений в электронной форме'},
#  {'customer': 'Акционерное общество Инжиниринговая компания "АСЭ"',
#   'link': 'http://www.zakupki.rosatom.ru/19082205361457',
#   'linkText': 'Право заключения договора на поставку товара по лоту №13996/1854 Куд5,6/П-19 «Поставка устройств импульсно-предохранительных для сооружения энергоблоков №5,6 для АЭС Куданкулам»',
#   'num': '190822/0536/1457',
#   'price': '19339929.41',
#   'type': 'Запрос предложений в электронной форме'},
#  {'customer': 'Федеральное государственное унитарное предприятие "Московское опытно-конструкторское бюро "Марс"',
#   'link': 'http://www.zakupki.rosatom.ru/19081458357045',
#   'linkText': 'Право заключения договора на Поставка оборудования Системы контрольно-измерительной-Тестер полупроводниковых приборов',
#   'num': '190814/58357/045',
#   'price': '6786006.67',
#   'type': 'Запрос предложений в электронной форме среди субъектов МСП'},
#  {'customer': 'Акционерное общество "Российский концерн по производству электрической и тепловой энергии на атомных станциях"',
#   'link': 'http://www.zakupki.rosatom.ru/19082205131241',
#   'linkText': 'Поставка ацетилена для выполнения работ по демонтажу технологического оборудования',
#   'num': '190822/0513/1241',
#   'price': '496800.00',
#   'type': 'Мелкая закупка'},
#  {'customer': 'Филиал АО "Концерн Росэнергоатом" "Калининская атомная станция"',
#   'link': 'http://www.zakupki.rosatom.ru/1908220615671',
#   'linkText': 'Право заключения договора на поставку запасных частей к насосам АЦНА, АЦВА и ЦНСА',
#   'num': '190822/0615/671',
#   'price': '22415806.83',
#   'type': 'Конкурс в электронной форме'},
#  {'customer': 'Акционерное Общество "Гринатом"',
#   'link': 'http://www.zakupki.rosatom.ru/1908070638298',
#   'linkText': 'Поставка мебели для сотрудников филиала АО «Гринатом» в г. Санкт-Петербург',
#   'num': '190807/0638/298',
#   'price': '480186.60',
#   'type': 'Мелкая закупка'},
#  {'customer': 'Общество с ограниченной ответственностью "Турбинные технологии ААЭМ"',
#   'link': 'http://www.zakupki.rosatom.ru/1908220599032',
#   'linkText': 'Поставка расходных материалов и запасных частей для оргтехники',
#   'num': '190822/0599/032',
#   'price': '151602.00',
#   'type': 'Мелкая закупка'},
#  {'customer': 'Филиал ОАО "Концерн Росэнергоатом" "Белоярская атомная станция"',
#   'link': 'http://www.zakupki.rosatom.ru/1908220670422',
#   'linkText': 'Право заключения договора на Поставка электроинструмента согласно спецификации',
#   'num': '190822/0670/422',
#   'price': '1239981.25',
#   'type': 'Запрос котировок в электронной форме среди субъектов МСП'}]

# %%
while True:
    try:
        nextPage = driver.find_element_by_xpath("//div[@class='tbl pages-list'][1]/div[@class='cell cell-left list']/ul[@class='clean horizontal']/li[@class='control'][3]/p/a")
        nextPage.click()
        #nextPage = driver.find_elements_by_xpath("/html/body/form[@id='form1']/div[@class='wrapper']/div[@class='body body-inner']/div[@class='body-column body-column-right content']/div[@class='tbl pages-list'][1]/div[@class='cell cell-left list']/ul[@class='clean horizontal']/li[@class='control'][3]/p/a")
        page=page+1
        btns = driver.find_elements_by_xpath("//td[@class='control']/img[@class='btm']")
        for t in range(len(btns)):
            btns[t].click()
        nums = driver.find_elements_by_xpath("//table/tbody/tr/td[@class='description']/p[1]")
        links = driver.find_elements_by_xpath("//table/tbody/tr/td[@class='description']/p[2]/a")
        prices = driver.find_elements_by_xpath("//table/tbody/tr/td[@class='price text-right']/p[1]")
        customers = driver.find_elements_by_xpath("//table/tbody/tr[((contains(@class,'odd') or contains(@class,'even')) and not (contains(@class,'description')))]/td[5]/p")
        types = driver.find_elements_by_xpath("//table/tbody/tr/td[@class='description']/div[@class='description']/p[2]/strong")
                
        #print(len(myArr))
        
        k=0
        endOfCicle=i+len(links)
        #print(endOfCicle)
        while i < endOfCicle:
            myArr.append(['','','','','',''])
            #print(len(myArr))
            i=i+1
            myArr[i][0]=nums[k].text    
            myArr[i][1]=links[k].text
            myArr[i][2]=links[k].get_attribute('href')
            myArr[i][3]=prices[k].text.replace(" ", "").replace(",", ".")
            myArr[i][4]=customers[k].text
            myArr[i][5]=types[k].text
            print(myArr[i][0]+'||'+myArr[i][1]+'||'+myArr[i][3]+'||'+myArr[i][4]+'||'+myArr[i][5])
            k=k+1    
        #if page==2: #отладочный останов на 2 странице
        #    break
    except NoSuchElementException:
        print("Oops!  That was no Next link.  It seems that it is finish...")
        break

print(len(myArr))        
        
driver.close()

#функция фильтрации данных
def myTendFilter(myArr, minPrice, maxPrice,keyWords,keyTenderTypes,customer):
    resArr=[['']*6]
    k=0
    for i in range(len(myArr)):
        pr=float(myArr[i][3])
        minPrice=float(minPrice)
        flag=0        
        if customer!='':    #если установлен заказчик        
            if myArr[i][4].find(customer)>=0:    #если заказчик соответствует
                if len(keyWords)>0:                #если помимо заказчика есть ключевые слова
                    for n in range(len(keyWords)):
                        if myArr[i][1].find(keyWords[n])>=0:
                            #print(myArr[i][1]+'=='+keyWords[n])
                            flag=1            
                else:                            #если нет ключевых слов
                    flag=1
        else:                #если заказчик не установлен
            for n in range(len(keyWords)):
                if myArr[i][1].find(keyWords[n])>=0:
                    #print(myArr[i][1]+'=='+keyWords[n])
                    flag=1
        
        if pr>=minPrice and flag==1:
            resArr.append(['','','','','',''])
            resArr[k][0]=myArr[i][0]    
            resArr[k][1]=myArr[i][1]
            resArr[k][2]=myArr[i][2]
            resArr[k][3]=myArr[i][3]
            resArr[k][4]=myArr[i][4]
            resArr[k][5]=myArr[i][5]
            #print(resArr[k][0]+'||'+resArr[k][1]+'||'+resArr[k][3]+'\n')
            k=k+1
    return resArr



#подготовка текста сообщения
def MailMessage(myArr,filterName,keyWords,guid):
    resKeyWords=''
    for s in range(len(keyWords)):
        resKeyWords=resKeyWords+'|'+keyWords[s]
        eMessage='<BR><BR><B>Выборка по фильтру:'+filterName+'</B> [ключевые слова:<i>'+resKeyWords+'</i>]<BR><table><tr><td>Номер закупки</td><td>Ссылка</td><td>Цена</td><td>Тип</td><td>Организатор</td><td>Варианты действий</td></tr>'
    for i in range(len(myArr)-1):        
        if i % 2 == 0:
            eMessage=eMessage+'<tr bgcolor="Gainsboro">'
        else:
            eMessage=eMessage+'<tr>'
        eMessage=eMessage+'<td>'+myArr[i][0]+'</td>'
        eMessage=eMessage+'<td><a href='+myArr[i][2]+'>'+myArr[i][1]+'</a></td>'
        eMessage=eMessage+'<td>'+str(myArr[i][3])+'</td>'        
        eMessage=eMessage+'<td>'+str(myArr[i][5])+'</td>'
        eMessage=eMessage+'<td>'+str(myArr[i][4])+'</td>'
        eMessage=eMessage+'<td><a href="http://smartchein.ru/bots/pyhello.php?user='+guid+'&show=tenders&action=mon&tenderid='+myArr[i][0].replace('/','')+'&desc='+myArr[i][1][0:150]+'">Отслеживать</a></td>'
        eMessage=eMessage+'</tr>'
    eMessage=eMessage+'</table><BR><b><a href="http://smartchein.ru/bots/pyhello.php?user='+guid+'&show=tenders">Список отслеживаемых тендеров</a><br><p color="red">ВНИМАНИЕ!!! ССЫЛКИ НА ОТСЛЕЖИВАНИЕ ЯВЛЯЮТСЯ ПЕРСОНАЛЬНЫМИ!!! НЕ ПЕРЕСЫЛАЙТЕ ДАННОЕ СООБЩЕНИЕ КОМУ-ЛИБО ВО ИЗБЕЖАНИЕ НЕСАНКЦИОНИРОВАННОГО ДОСТУПА К ПЕРЕЧНЮ ВАШИХ ТЕНДЕРОВ</p></b>'
    return eMessage

#sending mail function
def SendMail(to,subject,eMessage,msg):
    HOST = "mail.smartchein.ru"
    fro = "info@smartchein.ru"
        
    msg['Subject'] = subject
    msg['From'] = fro
    msg['To'] = to

    # Create the body of the message (a plain-text and an HTML version).
    #text = "Hi!\nHow are you?\nHere is the link you wanted:\nhttp://www.python.org"
    html = eMessage
    
    #part1 = MIMEText(text, 'plain')
    part2 = MIMEText(html, 'html')

    #msg.attach(part1)
    msg.attach(part2)
     
    #connect to server
    server = smtplib.SMTP(HOST,587)
    #login to mailbox
    server.login('info@smartchein.ru','scinfo_76589')
    server.sendmail(fro, to, msg.as_string())
    server.quit()
    return 1

#numerical filters section start =================================

#filters 
myFilters={'asu' : (15000000,' Системы контроля и управления с ценой > 15 000 000',['СКУ','АСУ','систем','автомати', 'шкаф', 'мпу', 'мщу', 'панел','измерит','оборуд','комплек'],''),
           'proj' : (350000,' Проектирование > 450 000',['проект','документ','разраб'],''),
           'rasu' : (3000000,' РАСУ > 3 000 000',[''],'Русатом Автоматизированные системы управления'),
           'oditz' : (8000000,' ОДИЦ > 8 000 000',[''],'пытно-демонстрационный'),
           'uemz' : (10000000,' УЭМЗ > 10 000 000',[''],'Уральский электромеханический завод'),
           'sniip' : (6000000,' СНИИП > 6 000 000',[''],'Институт приборостроения'),
           'electro' : (4000000,' Электрика > 4 000 000',['РЗ','релейн', 'КРУ', 'вольт', 'НКУ', ' напряжен', ' ток'],''),
           'ekra' : (400000,' Продукция ЭКРА > 400 000',['РЗ', 'релейн', 'ПА', 'противоавар', 'ЩПТ', 'постоянн', 'беспереб','НКУ', 'КРУ', 'ЭКРА', 'инвертор', 'выпрямител'],''),
           'svyaz' : (400000,' ВЧ связь > 400 000',['связь', 'ВЧ', 'фильтр', 'загради'],''),
           'bdk_nasos' : (1000000,' Насосное оборудование > 1 000 000',['насос', 'агрегат', 'запасн', 'запчасти', 'комплектующ','торц','уплотн'],''), 
           'bdk_baki' : (5000000,' Емкости и баки > 5 000 000',['бак', 'гидроемкост', 'емкост'],''), 
           'bdk_disel' : (10000000,' Дизель > 10 000 000',['САУ', 'ДГУ', 'дизел'],''),
           'bdk_asu' : (20000000,' АСУ > 20 000 000',['ПТК', 'АСУ', 'СНЭ', 'СКУ', 'ХВО', 'САР ТО', 'САОЗ', 'ESMI'],''), 
           #титан:
           'titan1' : (1000000,'НКУ с ценой > 1 млн.',['РУНН','НКУ','ГРЩ','ЩРГ','ЩПТ','Низковольт','КРАУ','РТЗО','КТПСН','распределительн'],''),
           'titan2' : (1000000,'IT с ценой > 1 млн.',['ЦОД','Дата центр','центр обработки данных'],''),
           'titan3' : (1000000,'АСУ с ценой > 1 млн.',['РЗА','мониторинг','СКУ','ПЗ','АИИСКУЭ','АСУТП','АСУ','автоматизирован','управления'],''),
           #кип
           'kip' : (4000000,'КИП с ценой > 4 млн.',['КИП', 'расход', 'ультразву', 'измер','уровн','давлен','метр','датчи','контрол','РОС','РИС','СУЭ ДАС','СПС','СУРГ'],''),
           #НИОКР
           'niokr' : (7000000,'НИОКР с ценой > 7 млн.',['НИОКР','ОКР','опыт','конструторск','исследоват'],''),
           #поковки
           'pokovki' : (2500000,'Поковки с ценой > 2,5 млн.',['поков','бандаж','обечай','обойм','седл','корпус','флан','кольц','сектор','рельс','колес','патруб'],'')
           
           }
#users
myUsers={'Alexey1' : ('Алексей','avkuryatov@yandex.ru',' Бот: Закупки Росатома: для Алексея','eRtm!5hdz1'),
         #'GOL' : ('Евгений','evgeny.golovanov99@gmail.com',' Бот: Закупки Росатома: для Евгения','eR!5HdZ_1'),
         'GOL' : ('Евгений','evsgolovanov@gmail.com',' Бот: Закупки Росатома: для Евгения','eR!5HdZ_1'),
         'BDK' : ('Ярослав','bdk@tehnab.ru',' Бот: Закупки Росатома: для Ярослава','wGhj5!420iRt'),
         'UPA' : ('Павел','upa@tehnab.ru',' Бот: Закупки Росатома: для Павла','vuT6eRW!po0'),
         'BAN' : ('Алексей','ban@tehnab.ru',' Бот: Закупки Росатома: для Алексея Богатова','vdcE!po06yH'),
         'KEY' : ('Валерияэ','key@tehnab.ru',' Бот: Закупки Росатома: для Валерии Ковалевой', 'BV3d6Taldx!_65F'),
         #ПАМ
         'PiterAM' : ('Питератоммаш','piteratommash@mail.ru',' Бот: Закупки Росатома: для Питератоммаш','sKn3shg9!6B'),
         #АГАТ-КИП
         'Agat' : ('Константин', 'agat-kip.market@yandex.ru',' Бот: Закупки Росатома: для АГАТ-КИП','fg!7tEWaqloX'),
         #титан:
         'Chagin' : ('Денис Чагин','dionis-spb@yandex.ru',' Бот: Закупки Росатома: для Чагина','bUf1r!_YhS'),
         'Toropov' : ('Александр Торопов','toropov.aa@szte.ru',' Бот: Закупки Росатома: для Торопова','nohG6!gR7'),
         'Bessonov' : ('Павел Бессонов','Bessonov.pe@mail.ru',' Бот: Закупки Росатома: для Бессонова','FQapod856dY!v'),
         'Apanuk' : ('Екатерина Апанюк', 'apanuk.es@szte.ru','Бот: Закупки Росатома: для Апанюк','FQapod856dY!v')     
         }
#filers for users
userFiltersDict={
                'Alexey1' : ['asu','proj','electro','rasu','uemz','sniip','pokovki'], 
                'BAN' : ['asu','proj','electro','kip','ekra','rasu','uemz','sniip','pokovki','bdk_nasos','bdk_baki','bdk_asu','bdk_disel','svyaz','oditz'], 
                'KEY' : ['asu','proj','electro','kip','ekra','rasu','uemz','sniip','pokovki','bdk_nasos','bdk_baki','bdk_asu','bdk_disel','svyaz','oditz'], 
                'GOL' : ['kip','rasu','sniip'], 
                'BDK' : ['bdk_nasos','bdk_baki','bdk_asu','bdk_disel'], 
                'PiterAM' : ['bdk_nasos','bdk_baki'], 
                'Agat' : ['kip','rasu','sniip'], 
                'UPA' : ['ekra','svyaz'],
                'Chagin' : ['titan1','titan2', 'titan3'], 
                'Bessonov' : ['titan1','titan2', 'titan3'],
                'Toropov' : ['titan1','titan2', 'titan3'],
                'Apanuk' : ['titan1','titan2', 'titan3']
                }
#userFiltersDict={'GOL' : ['kip','rasu','sniip']}




maxPrice=''
keyTenderTypes=''
eMessage=''
for key, value in userFiltersDict.items():
    #адресат 1
    fio = myUsers[key][0]
    emailto=myUsers[key][1]
    MessageName=dtnow+':'+myUsers[key][2]
    guid=myUsers[key][3]
    #print(MessageName)
    
    #filter
    for num in range(len(value)):        
        filterId = value[num]
        minPrice = myFilters[filterId][0]
        filterName = myFilters[filterId][1]
        keyWords = myFilters[filterId][2]
        customer = myFilters[filterId][3]
        #print(keyWords)
        #start filtering
        resArr=myTendFilter(myArr, minPrice, maxPrice,keyWords,keyTenderTypes,customer)
        #create message table    
        eMessage=eMessage+MailMessage(resArr,filterName,keyWords,guid)
    
    #sending mail to person
    #sending message    
    msg = MIMEMultipart('alternative')
    SendMail(emailto,MessageName,eMessage,msg)
    eMessage=''
